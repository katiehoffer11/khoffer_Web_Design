# %%
import pandas as pd

# %%
csv = "city_weather_csv"

city_weather_df = pd.read_csv(csv)

print(city_weather_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Lat</th>
#       <th>Lon</th>
#       <th>Max Temp</th>
#       <th>Humidity (%)</th>
#       <th>Cloudiness (%)</th>
#       <th>Wind Speed (mph)</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>clyde river</td>
#       <td>CA</td>
#       <td>70.47</td>
#       <td>-68.59</td>
#       <td>28.40</td>
#       <td>92</td>
#       <td>90</td>
#       <td>3.36</td>
#       <td>1590259298</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>bredasdorp</td>
#       <td>ZA</td>
#       <td>-34.53</td>
#       <td>20.04</td>
#       <td>59.00</td>
#       <td>62</td>
#       <td>0</td>
#       <td>5.82</td>
#       <td>1590259299</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>jamestown</td>
#       <td>US</td>
#       <td>42.10</td>
# ...
